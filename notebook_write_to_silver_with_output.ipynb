# %% [markdown]
# # NYC Taxi

# %%
from pyspark.sql import functions as F

path = "abfss://41cad357-4eca-4164-9ed3-989bfbd2726a@onelake.dfs.fabric.microsoft.com/2dcd1ee8-dc34-4b11-a8e1-bf225ce91bdf/Tables/dbo/nyc_taxi/"

files = mssparkutils.fs.ls(path)
for f in files:
    print(f.name)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 3, Finished, Available, Finished, False)
# yellow_tripdata_2022-01.parquet
# yellow_tripdata_2022-02.parquet
# yellow_tripdata_2022-03.parquet
# yellow_tripdata_2022-04.parquet
# yellow_tripdata_2022-05.parquet
# yellow_tripdata_2022-06.parquet
# yellow_tripdata_2022-07.parquet
# yellow_tripdata_2022-08.parquet
# yellow_tripdata_2022-09.parquet
# yellow_tripdata_2022-10.parquet
# yellow_tripdata_2022-11.parquet
# yellow_tripdata_2022-12.parquet
# yellow_tripdata_2023-01.parquet
# yellow_tripdata_2023-02.parquet
# yellow_tripdata_2023-03.parquet
# yellow_tripdata_2023-04.parquet
# yellow_tripdata_2023-05.parquet
# yellow_tripdata_2023-06.parquet
# yellow_tripdata_2023-07.parquet
# yellow_tripdata_2023-08.parquet
# yellow_tripdata_2023-09.parquet
# yellow_tripdata_2023-10.parquet
# yellow_tripdata_2023-11.parquet
# yellow_tripdata_2023-12.parquet
# yellow_tripdata_2024-01.parquet
# yellow_tripdata_2024-02.parquet
# yellow_tripdata_2024-03.parquet
# yellow_tripdata_2024-04.parquet
# yellow_tripdata_2024-05.parquet
# yellow_tripdata_2024-06.parquet
# yellow_tripdata_2024-07.parquet
# yellow_tripdata_2024-08.parquet
# yellow_tripdata_2024-09.parquet
# yellow_tripdata_2024-10.parquet
# yellow_tripdata_2024-11.parquet
# yellow_tripdata_2024-12.parquet
# yellow_tripdata_2025-01.parquet
# yellow_tripdata_2025-02.parquet
# yellow_tripdata_2025-03.parquet
# yellow_tripdata_2025-04.parquet
# yellow_tripdata_2025-05.parquet
# yellow_tripdata_2025-06.parquet
# yellow_tripdata_2025-07.parquet
# yellow_tripdata_2025-08.parquet
# yellow_tripdata_2025-09.parquet
# yellow_tripdata_2025-10.parquet
# yellow_tripdata_2025-11.parquet
# yellow_tripdata_2025-12.parquet

# %%
spark.conf.set("spark.sql.parquet.enableVectorizedReader", "false")

df = spark.read.format("parquet").load(path + "yellow_tripdata_2022-01.parquet")

df.printSchema()
df.show(5)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 4, Finished, Available, Finished, False)
# root
#  |-- VendorID: long (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: double (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: double (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: long (nullable = true)
#  |-- DOLocationID: long (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- airport_fee: double (nullable = true)
#
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|airport_fee|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |       1| 2022-01-01 00:35:40|  2022-01-01 00:53:29|            2.0|          3.8|       1.0|                 N|         142|         236|           1|       14.5|  3.0|    0.5|      3.65|         0.0|                  0.3|       21.95|                 2.5|        0.0|
# |       1| 2022-01-01 00:33:43|  2022-01-01 00:42:07|            1.0|          2.1|       1.0|                 N|         236|          42|           1|        8.0|  0.5|    0.5|       4.0|         0.0|                  0.3|        13.3|                 0.0|        0.0|
# |       2| 2022-01-01 00:53:21|  2022-01-01 01:02:19|            1.0|         0.97|       1.0|                 N|         166|         166|           1|        7.5|  0.5|    0.5|      1.76|         0.0|                  0.3|       10.56|                 0.0|        0.0|
# |       2| 2022-01-01 00:25:21|  2022-01-01 00:35:23|            1.0|         1.09|       1.0|                 N|         114|          68|           2|        8.0|  0.5|    0.5|       0.0|         0.0|                  0.3|        11.8|                 2.5|        0.0|
# |       2| 2022-01-01 00:36:48|  2022-01-01 01:14:20|            1.0|          4.3|       1.0|                 N|          68|         163|           1|       23.5|  0.5|    0.5|       3.0|         0.0|                  0.3|        30.3|                 2.5|        0.0|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# only showing top 5 rows

# %%
df_2025 = spark.read.format("parquet").load(path + "yellow_tripdata_2025-05.parquet")

df_2025.printSchema()
df_2025.show(5)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 5, Finished, Available, Finished, False)
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- Airport_fee: double (nullable = true)
#  |-- cbd_congestion_fee: double (nullable = true)
#
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+------------------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|Airport_fee|cbd_congestion_fee|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+------------------+
# |       1| 2025-05-01 00:07:06|  2025-05-01 00:24:15|              1|          3.7|         1|                 N|         140|         202|           1|       18.4| 4.25|    0.5|      4.85|         0.0|                  1.0|        29.0|                 2.5|        0.0|              0.75|
# |       2| 2025-05-01 00:07:44|  2025-05-01 00:14:27|              1|         1.03|         1|                 N|         234|         161|           1|        8.6|  1.0|    0.5|       4.3|         0.0|                  1.0|       18.65|                 2.5|        0.0|              0.75|
# |       2| 2025-05-01 00:15:56|  2025-05-01 00:23:53|              1|         1.57|         1|                 N|         161|         234|           2|       10.0|  1.0|    0.5|       0.0|         0.0|                  1.0|       15.75|                 2.5|        0.0|              0.75|
# |       2| 2025-05-01 00:00:09|  2025-05-01 00:25:29|              1|         9.48|         1|                 N|         138|          90|           1|       40.8|  6.0|    0.5|      11.7|        6.94|                  1.0|       71.94|                 2.5|       1.75|              0.75|
# |       2| 2025-05-01 00:45:07|  2025-05-01 00:52:45|              1|          1.8|         1|                 N|          90|         231|           1|       10.0|  1.0|    0.5|       1.5|         0.0|                  1.0|       17.25|                 2.5|        0.0|              0.75|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+------------------+
# only showing top 5 rows

# %%
from pyspark.sql import functions as F

spark.conf.set("spark.sql.parquet.enableVectorizedReader", "false")

needed_cols = [
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime", 
    "PULocationID",
    "DOLocationID",
    "trip_distance",
    "fare_amount",
    "total_amount"
]

dfs = []

for f in files:
    try:
        df_temp = spark.read.format("parquet").load(path + f.name)
        df_temp = df_temp.select(needed_cols)
        dfs.append(df_temp)
        print(f"OK: {f.name}")
    except Exception as e:
        print(f"Error: {f.name} -> {str(e)[:100]}")

from functools import reduce
df_all = reduce(lambda a, b: a.union(b), dfs)

print("Total number of rows:", df_all.count())
df_all.show(5)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 6, Finished, Available, Finished, False)
# OK: yellow_tripdata_2022-01.parquet
# OK: yellow_tripdata_2022-02.parquet
# OK: yellow_tripdata_2022-03.parquet
# OK: yellow_tripdata_2022-04.parquet
# OK: yellow_tripdata_2022-05.parquet
# OK: yellow_tripdata_2022-06.parquet
# OK: yellow_tripdata_2022-07.parquet
# OK: yellow_tripdata_2022-08.parquet
# OK: yellow_tripdata_2022-09.parquet
# OK: yellow_tripdata_2022-10.parquet
# OK: yellow_tripdata_2022-11.parquet
# OK: yellow_tripdata_2022-12.parquet
# OK: yellow_tripdata_2023-01.parquet
# OK: yellow_tripdata_2023-02.parquet
# OK: yellow_tripdata_2023-03.parquet
# OK: yellow_tripdata_2023-04.parquet
# OK: yellow_tripdata_2023-05.parquet
# OK: yellow_tripdata_2023-06.parquet
# OK: yellow_tripdata_2023-07.parquet
# OK: yellow_tripdata_2023-08.parquet
# OK: yellow_tripdata_2023-09.parquet
# OK: yellow_tripdata_2023-10.parquet
# OK: yellow_tripdata_2023-11.parquet
# OK: yellow_tripdata_2023-12.parquet
# OK: yellow_tripdata_2024-01.parquet
# OK: yellow_tripdata_2024-02.parquet
# OK: yellow_tripdata_2024-03.parquet
# OK: yellow_tripdata_2024-04.parquet
# OK: yellow_tripdata_2024-05.parquet
# OK: yellow_tripdata_2024-06.parquet
# OK: yellow_tripdata_2024-07.parquet
# OK: yellow_tripdata_2024-08.parquet
# OK: yellow_tripdata_2024-09.parquet
# OK: yellow_tripdata_2024-10.parquet
# OK: yellow_tripdata_2024-11.parquet
# OK: yellow_tripdata_2024-12.parquet
# OK: yellow_tripdata_2025-01.parquet
# OK: yellow_tripdata_2025-02.parquet
# OK: yellow_tripdata_2025-03.parquet
# OK: yellow_tripdata_2025-04.parquet
# OK: yellow_tripdata_2025-05.parquet
# OK: yellow_tripdata_2025-06.parquet
# OK: yellow_tripdata_2025-07.parquet
# OK: yellow_tripdata_2025-08.parquet
# OK: yellow_tripdata_2025-09.parquet
# OK: yellow_tripdata_2025-10.parquet
# OK: yellow_tripdata_2025-11.parquet
# OK: yellow_tripdata_2025-12.parquet
# Total number of rows: 167858646
# +--------------------+---------------------+------------+------------+-------------+-----------+------------+
# |tpep_pickup_datetime|tpep_dropoff_datetime|PULocationID|DOLocationID|trip_distance|fare_amount|total_amount|
# +--------------------+---------------------+------------+------------+-------------+-----------+------------+
# | 2022-01-01 00:35:40|  2022-01-01 00:53:29|         142|         236|          3.8|       14.5|       21.95|
# | 2022-01-01 00:33:43|  2022-01-01 00:42:07|         236|          42|          2.1|        8.0|        13.3|
# | 2022-01-01 00:53:21|  2022-01-01 01:02:19|         166|         166|         0.97|        7.5|       10.56|
# | 2022-01-01 00:25:21|  2022-01-01 00:35:23|         114|          68|         1.09|        8.0|        11.8|
# | 2022-01-01 00:36:48|  2022-01-01 01:14:20|          68|         163|          4.3|       23.5|        30.3|
# +--------------------+---------------------+------------+------------+-------------+-----------+------------+
# only showing top 5 rows

# %%
display(df_all)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 7, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, e974dd65-1997-4848-a875-1a95d57c93c4)

# %%
df_clean = df_all.dropna(how='all')
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 8, Finished, Available, Finished, False)

# %%
df_clean.printSchema()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 9, Finished, Available, Finished, False)
# root
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- PULocationID: long (nullable = true)
#  |-- DOLocationID: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- total_amount: double (nullable = true)

# %%
from pyspark.sql.types import IntegerType
df_clean = df_clean.withColumn("PULocationID", df_clean.PULocationID.cast(IntegerType()))
df_clean = df_clean.withColumn("DOLocationID",df_clean.DOLocationID.cast(IntegerType()))
df_clean.printSchema()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 10, Finished, Available, Finished, False)
# root
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- total_amount: double (nullable = true)

# %%
df_clean.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 11, Finished, Available, Finished, False)
# 167858646

# %%
df_clean = df_clean.where((df_clean['trip_distance'] >0) & (df_clean['fare_amount'] > 0) & (df_clean['total_amount'] > 0))
display(df_clean)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 12, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 1a6abcf3-11e5-4e8a-8f47-00ef214e6923)

# %%
df_clean.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 13, Finished, Available, Finished, False)
# 160453044

# %%
numeric_column = [
    "trip_distance",
    "fare_amount",
    "total_amount"
]
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 14, Finished, Available, Finished, False)

# %%
import pyspark.sql.functions as f
for column in numeric_column:
    less_Q1 = 'less_Q1_{}'.format(column)
    more_Q3 = 'more_Q3_{}'.format(column)
    Q1 = 'Q1_{}'.format(column)
    Q3 = 'Q3_{}'.format(column)

    #Q1 : First Quartile., Q3 : Third Quartile
    Q1 = df_clean.approxQuantile(column, [0.25], 0.01)
    Q3 = df_clean.approxQuantile(column, [0.75], 0.01)

    #IQR : Inter Quantile Range
    # We need to define the index [0], as Q1 & Q3 are a set of lists., to perform a mathematical operation
    # Q1 & Q3 are defined separately so as to have a clear indication on First Quantile & 3rd Quantile
    IQR = Q3[0] - Q1[0]
    
    less_Q1 = Q1[0] - 1.5*IQR
    more_Q3 = Q3[0] + 1.5*IQR
    isOutlierCol = 'is_outlier_{}'.format(column)
    df_clean = df_clean.withColumn(isOutlierCol,f.when((df_clean[column] > more_Q3) | (df_clean[column] < less_Q1),1).otherwise(0))
# Selecting the specific columns which we added above, to check if there are any outliers
selected_columns = [column for column in df_clean.columns if column.startswith("is_outlier")]

#Adding all the outlier columns into a new column "total_outliers, to see the total number of outliers"
df_clean = df_clean.withColumn('total_outliers', sum(df_clean[column] for column in selected_columns))
display(df_clean)
# df_clean = df_clean.drop(*[column for column in df_clean.columns if column.startswith("is_outlier")])
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 15, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 03bcdd08-d5bd-4f93-b13f-8c530aab7ae3)

# %%
df_clean = df_clean.filter(df_clean.total_outliers <= 2)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 16, Finished, Available, Finished, False)

# %%
df_clean.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 17, Finished, Available, Finished, False)
# 147000735

# %%
df_clean = df_clean.drop(*[column for column in df_clean.columns if column.startswith("is_outlier")])
display(df_clean)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 18, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, ff24652a-c12e-4ffe-8d82-eaed3fa81886)

# %%
df_clean = df_clean.filter(df_clean['tpep_pickup_datetime'] < df_clean['tpep_dropoff_datetime'])
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 19, Finished, Available, Finished, False)

# %%
df_clean.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 20, Finished, Available, Finished, False)
# 146481576

# %%
df_clean = df_clean.dropDuplicates()
df_clean.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 21, Finished, Available, Finished, False)
# 146481574

# %%
display(df_clean)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 22, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 292fc38b-fe20-4405-ae39-32090fad35c5)

# %%
total_count = df_clean.count()
bad_count = df_clean.filter(df_clean.total_amount < df_clean.fare_amount).count()
ratio = bad_count / total_count * 100 
ratio
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 23, Finished, Available, Finished, False)
# 0.005399996589332117

# %%
from pyspark.sql.functions import isnan, col
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 24, Finished, Available, Finished, False)

# %%
df_clean.filter(df_clean["trip_distance"].isNull() | isnan("trip_distance")).count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 25, Finished, Available, Finished, False)
# 0

# %%
df_clean.filter(df_clean["fare_amount"].isNull() | isnan("fare_amount")).count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 26, Finished, Available, Finished, False)
# 0

# %%
df_clean.filter(df_clean["total_amount"].isNull() | isnan("total_amount")).count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 27, Finished, Available, Finished, False)
# 0

# %%
df_clean.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 28, Finished, Available, Finished, False)
# 146481574

# %%
display(df_clean)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 29, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 06b4c957-197f-46b5-81ce-42339e50e432)

# %%
df_clean = df_clean.dropDuplicates([
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime",
    "PULocationID",
    "DOLocationID",
    "trip_distance"
])
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 30, Finished, Available, Finished, False)

# %%
from pyspark.sql import functions as F
df_clean = df_clean.withColumn("pickup_year",F.year("tpep_pickup_datetime"))
df_clean = df_clean.withColumn("pickup_month",F.month("tpep_pickup_datetime"))
df_clean = df_clean.withColumn("pickup_date",F.to_date("tpep_pickup_datetime"))
df_clean = df_clean.withColumn("pickup_hour",F.hour("tpep_pickup_datetime"))
df_clean = df_clean.withColumn("pickup_day_of_week",F.dayofweek("tpep_pickup_datetime"))
df_clean = df_clean.withColumn("pickup_day", F.dayofmonth("tpep_pickup_datetime"))
df_clean = df_clean.withColumn("trip_duration_min", (F.unix_timestamp("tpep_dropoff_datetime")- F.unix_timestamp("tpep_pickup_datetime"))/60)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 31, Finished, Available, Finished, False)

# %%
df_clean.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 32, Finished, Available, Finished, False)
# 146474188

# %%
numberRows = df_clean.count()
print(numberRows)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 33, Finished, Available, Finished, False)
# 146474188

# %%
numberRows = df_clean.count()
print("Total amount NULL - values between columns:")
for k in df_clean.columns:
    nullRows = df_clean.filter(df_clean[f"{k}"].isNull()).count()
    print(f"{k} - {nullRows}")
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 34, Finished, Available, Finished, False)
# Total amount NULL - values between columns:
# tpep_pickup_datetime - 0
# tpep_dropoff_datetime - 0
# PULocationID - 0
# DOLocationID - 0
# trip_distance - 0
# fare_amount - 0
# total_amount - 0
# total_outliers - 0
# pickup_year - 0
# pickup_month - 0
# pickup_date - 0
# pickup_hour - 0
# pickup_day_of_week - 0
# pickup_day - 0
# trip_duration_min - 0

# %%
df_clean.printSchema()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 35, Finished, Available, Finished, False)
# root
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- total_outliers: integer (nullable = false)
#  |-- pickup_year: integer (nullable = true)
#  |-- pickup_month: integer (nullable = true)
#  |-- pickup_date: date (nullable = true)
#  |-- pickup_hour: integer (nullable = true)
#  |-- pickup_day_of_week: integer (nullable = true)
#  |-- pickup_day: integer (nullable = true)
#  |-- trip_duration_min: double (nullable = true)

# %%
numberRows = df_clean.select("trip_distance","fare_amount", "total_amount").count()
# print("Total amount NULL - values between columns:")
# for k in df_clean.columns:
#     nullRows = df_clean.filter(df_clean[f"{k}"].isNull()).count()
#     print(f"{k} - {nullRows}")
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 36, Finished, Available, Finished, False)

# %%
display(df_clean)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 37, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, a1072355-9ecb-46a7-a773-8bb42c237870)

# %%
df_clean.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema","true") \
    .saveAsTable("silver_nyc_taxi")
print("Saved in Silver!")
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 38, Finished, Available, Finished, False)
# Saved in Silver!

# %% [markdown]
# ### OpenAQ (Air Quality)

# %%
df_aq = spark.sql("SELECT * FROM Silver.dbo.raw_openaq")
display(df_aq)
print(df_aq.count())
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 39, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, a118e516-94f0-4bf9-a42d-1315ad287116)
# 234

# %%
df_aq.printSchema()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 40, Finished, Available, Finished, False)
# root
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- locality: string (nullable = true)
#  |-- timezone: string (nullable = true)
#  |-- sensors.id: long (nullable = true)
#  |-- sensors.name: string (nullable = true)
#  |-- sensors.parameter.id: long (nullable = true)
#  |-- sensors.parameter.name: string (nullable = true)
#  |-- sensors.parameter.units: string (nullable = true)
#  |-- sensors.parameter.displayName: string (nullable = true)
#  |-- coordinates.latitude: double (nullable = true)
#  |-- coordinates.longitude: double (nullable = true)
#  |-- distance: double (nullable = true)
#  |-- datetimeFirst.utc: timestamp (nullable = true)
#  |-- datetimeFirst.local: string (nullable = true)
#  |-- datetimeLast.utc: timestamp (nullable = true)
#  |-- datetimeLast.local: string (nullable = true)

# %%
from pyspark.sql import functions as F
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 41, Finished, Available, Finished, False)

# %%
df_aq = df_aq.select(
    "id",
    "name",
    "locality",
    "timezone",
    "`sensors.id`",
    "`sensors.parameter.name`",
    "`sensors.parameter.units`",
    "`coordinates.latitude`",
    "`coordinates.longitude`",
    "`datetimeFirst.utc`",
    "`datetimeLast.utc`"
)
df_aq.printSchema()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 42, Finished, Available, Finished, False)
# root
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- locality: string (nullable = true)
#  |-- timezone: string (nullable = true)
#  |-- sensors.id: long (nullable = true)
#  |-- sensors.parameter.name: string (nullable = true)
#  |-- sensors.parameter.units: string (nullable = true)
#  |-- coordinates.latitude: double (nullable = true)
#  |-- coordinates.longitude: double (nullable = true)
#  |-- datetimeFirst.utc: timestamp (nullable = true)
#  |-- datetimeLast.utc: timestamp (nullable = true)

# %%
df_aq.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 43, Finished, Available, Finished, False)
# 234

# %%
df_aq = df_aq.filter(df_aq["`datetimeFirst.utc`"] <= df_aq["`datetimeLast.utc`"])
df_aq.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 44, Finished, Available, Finished, False)
# 234

# %%
unique = df_aq.select("id").distinct().count()
display(unique)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 45, Finished, Available, Finished, False)
# 63

# %%
df_aq = df_aq.drop_duplicates()
df_aq.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 46, Finished, Available, Finished, False)
# 234

# %%
display(df_aq)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 47, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, d4a6a8c0-05d0-4bf6-8284-3d50613df4fa)

# %%
df_aq = df_aq.filter(df_aq["`coordinates.latitude`"].isNotNull() & df_aq["`coordinates.longitude`"].isNotNull())
print("Total count after filtering of coordinates:", df_aq.count())
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 48, Finished, Available, Finished, False)
# Total count after filtering of coordinates: 234

# %%
df_aq = df_aq.drop_duplicates(["id", "sensors.id"])
print("Total amount after dropping duplicates on id and sensors.id:", df_aq.count())
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 49, Finished, Available, Finished, False)
# Total amount after dropping duplicates on id and sensors.id: 234

# %%
from pyspark.sql.functions import col
nullColumns = []
numRows = df_aq.count()
print("The total count of NULL values:")
for k in df_aq.columns:
     null_Rows = df_aq.filter(col(f"`{k}`").isNull()).count()
     print(f"{k} - {null_Rows} ")
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 50, Finished, Available, Finished, False)
# The total count of NULL values:
# id - 0
# name - 0
# locality - 192
# timezone - 0
# sensors.id - 0
# sensors.parameter.name - 0
# sensors.parameter.units - 0
# coordinates.latitude - 0
# coordinates.longitude - 0
# datetimeFirst.utc - 0
# datetimeLast.utc - 0

# %%
df_aq = df_aq.na.fill(value='Unknown', subset = ['locality'])
display(df_aq)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 51, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 0823b3d2-87b7-4101-b74b-f60d2b2d6aae)

# %%
df_aq.printSchema()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 52, Finished, Available, Finished, False)
# root
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- locality: string (nullable = false)
#  |-- timezone: string (nullable = true)
#  |-- sensors.id: long (nullable = true)
#  |-- sensors.parameter.name: string (nullable = true)
#  |-- sensors.parameter.units: string (nullable = true)
#  |-- coordinates.latitude: double (nullable = true)
#  |-- coordinates.longitude: double (nullable = true)
#  |-- datetimeFirst.utc: timestamp (nullable = true)
#  |-- datetimeLast.utc: timestamp (nullable = true)

# %%
is_Nan = df_aq.filter(F.isnan("`coordinates.latitude`") | F.isnan("`coordinates.longitude`"))
print(f"Total count of Nan value: {is_Nan.count()}")
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 53, Finished, Available, Finished, False)
# Total count of Nan value: 0

# %%
df_aq.write.format("delta").mode("overwrite").saveAsTable("Silver.dbo.silver_openaq_locations")
print("Saved in Silver!")
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 54, Finished, Available, Finished, False)
# Saved in Silver!

# %%
import requests
import time
from pyspark.sql import functions as F
df_aq_meas = df_aq.select(
    F.col("id"), 
    F.col("`sensors.id`").alias("sensor_id"), 
    F.col("`sensors.parameter.name`").alias("parameter"))
print(df_aq_meas)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 55, Finished, Available, Finished, False)
# DataFrame[id: bigint, sensor_id: bigint, parameter: string]

# %%
from datetime import datetime, timedelta

months = []
current = datetime(2022, 1, 1)
while current <= datetime(2025, 12, 1):
    next_month = datetime(current.year + (current.month == 12), 
                         (current.month % 12) + 1, 1)
    months.append((
        current.strftime("%Y-%m-%dT00:00:00Z"),
        (next_month - timedelta(seconds=1)).strftime("%Y-%m-%dT23:59:59Z")
    ))
    current = next_month

print(f"Total count of months: {len(months)}")
print(months[:3])
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 56, Finished, Available, Finished, False)
# Total count of months: 48
# [('2022-01-01T00:00:00Z', '2022-01-31T23:59:59Z'), ('2022-02-01T00:00:00Z', '2022-02-28T23:59:59Z'), ('2022-03-01T00:00:00Z', '2022-03-31T23:59:59Z')]

# %%
import requests
import time
from datetime import datetime, timedelta

sensors_list = df_aq_meas.collect()
all_measurements = []

for s in sensors_list:
    location_id = s[0]
    sensor_id = s[1]
    parameter = s[2]
    
    for date_from, date_to in months:
        page = 1
        retries = 0
        
        while True:
            url = f"https://api.openaq.org/v3/sensors/{sensor_id}/measurements"
            params = {
                "datetime_from": date_from,
                "datetime_to": date_to,
                "limit": 1000,
                "page": page
            }
            headers = {"X-API-Key": "30e0ed845a7c170412423e53cccdcc77d8168a2c51b14af06c667c02a4b44601"}
            
            response = requests.get(url, params=params, headers=headers, timeout=30)
            
            if response.status_code in [408, 500]:
                retries += 1
                if retries >= 3:
                    print(f"Miss sensor {sensor_id} {date_from[:7]}")
                    break
                time.sleep(5)
                continue
                
            if response.status_code == 429:
                time.sleep(10)
                continue
                
            if response.status_code != 200:
                print(f"Miss sensor {sensor_id}: status {response.status_code}")
                break
                
            data = response.json()
            results = data.get("results", [])
            
            if not results:
                break
                
            for r in results:
                all_measurements.append({
                    "location_id": location_id,
                    "sensor_id": sensor_id,
                    "parameter": parameter,
                    "value": r["value"],
                    "datetime_from_utc": r["period"]["datetimeFrom"]["utc"],
                    "datetime_to_utc": r["period"]["datetimeTo"]["utc"]
                })
            
            print(f"Sensor {sensor_id} {date_from[:7]}: {len(results)} rows")
            
            if len(results) < 1000:
                break
                
            page += 1
            time.sleep(1)

print(f"All measurements: {len(all_measurements)}")
df_measurements = spark.createDataFrame(all_measurements)
df_measurements.write.format("delta").mode("overwrite").saveAsTable("Bronze.dbo.raw_openaq_measurements")
print("Saved in Bronze!")
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 57, Finished, Available, Finished, False)
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 671: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 673: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 674: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1097: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1098: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1099: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1102: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1103: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1106: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1152: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1121: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1128: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1143: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1145: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1146: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1147: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1522: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1523: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1534: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1535: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 1536: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272250: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 4272431: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 5077566: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 1758: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3950: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3951: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 3952: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272273: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 4272290: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 1761: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3637: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3638: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# Miss sensor 3639: status 401
# ...
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915686: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915687: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915688: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 15915689: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083421: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083422: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083423: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083424: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# Miss sensor 16083425: status 401
# All measurements: 0
# ---------------------------------------------------------------------------
# PySparkValueError                         Traceback (most recent call last)
# Cell In[170], line 70
#      67             time.sleep(1)
#      69 print(f"All measurements: {len(all_measurements)}")
# ---> 70 df_measurements = spark.createDataFrame(all_measurements)
#      71 df_measurements.write.format("delta").mode("overwrite").saveAsTable("Bronze.dbo.raw_openaq_measurements")
#      72 print("Saved in Bronze!")
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/session.py:1443, in SparkSession.createDataFrame(self, data, schema, samplingRatio, verifySchema)
#    1438 if has_pandas and isinstance(data, pd.DataFrame):
#    1439     # Create a DataFrame from pandas DataFrame.
#    1440     return super(SparkSession, self).createDataFrame(  # type: ignore[call-overload]
#    1441         data, schema, samplingRatio, verifySchema
#    1442     )
# -> 1443 return self._create_dataframe(
#    1444     data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#    1445 )
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/session.py:1485, in SparkSession._create_dataframe(self, data, schema, samplingRatio, verifySchema)
#    1483     rdd, struct = self._createFromRDD(data.map(prepare), schema, samplingRatio)
#    1484 else:
# -> 1485     rdd, struct = self._createFromLocal(map(prepare, data), schema)
#    1486 assert self._jvm is not None
#    1487 jrdd = self._jvm.SerDeUtil.toJavaArray(rdd._to_java_object_rdd())
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/session.py:1093, in SparkSession._createFromLocal(self, data, schema)
#    1090     data = list(data)
#    1092 if schema is None or isinstance(schema, (list, tuple)):
# -> 1093     struct = self._inferSchemaFromList(data, names=schema)
#    1094     converter = _create_converter(struct)
#    1095     tupled_data: Iterable[Tuple] = map(converter, data)
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/session.py:948, in SparkSession._inferSchemaFromList(self, data, names)
#     933 """
#     934 Infer schema from list of Row, dict, or tuple.
#     935
#    (...)
#     945 :class:`pyspark.sql.types.StructType`
#     946 """
#     947 if not data:
# --> 948     raise PySparkValueError(
#     949         error_class="CANNOT_INFER_EMPTY_SCHEMA",
#     950         message_parameters={},
#     951     )
#     952 infer_dict_as_struct = self._jconf.inferDictAsStruct()
#     953 infer_array_from_first_element = self._jconf.legacyInferArrayTypeFromFirstElement()
#
# PySparkValueError: [CANNOT_INFER_EMPTY_SCHEMA] Can not infer schema from empty dataset.

# %%
# for checking the hypothesis
import requests
headers = {"X-API-Key": "30e0ed845a7c170412423e53cccdcc77d8168a2c51b14af06c667c02a4b44601"}

response = requests.get(
    "https://api.openaq.org/v3/sensors/1146/measurements",
    params={
    "datetime_from": "2022-01-01T00:00:00Z",
    "datetime_to": "2025-12-31T23:59:59Z",
    "limit": 5,
    "page": 1
    },
    headers=headers
)
print(response.status_code)
print(response.json())
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 59, Finished, Available, Finished, False)
# 401
# {'detail': 'Invalid credentials'}

# %%
df_meas = spark.sql("SELECT * FROM Bronze.dbo.raw_openaq_measurements")
df_meas.printSchema()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 60, Finished, Available, Finished, False)
# root
#  |-- datetime_from_utc: string (nullable = true)
#  |-- datetime_to_utc: string (nullable = true)
#  |-- location_id: long (nullable = true)
#  |-- parameter: string (nullable = true)
#  |-- sensor_id: long (nullable = true)
#  |-- value: double (nullable = true)

# %%
df_meas = df_meas.withColumn("datetime_from_utc", df_meas.datetime_from_utc.cast("timestamp"))
df_meas = df_meas.withColumn("datetime_to_utc", df_meas.datetime_to_utc.cast("timestamp"))
df_meas = df_meas.withColumn("location_id", df_meas.location_id.cast("Integer"))
df_meas = df_meas.withColumn("sensor_id", df_meas.sensor_id.cast("Integer"))
df_meas.printSchema()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 61, Finished, Available, Finished, False)
# root
#  |-- datetime_from_utc: timestamp (nullable = true)
#  |-- datetime_to_utc: timestamp (nullable = true)
#  |-- location_id: integer (nullable = true)
#  |-- parameter: string (nullable = true)
#  |-- sensor_id: integer (nullable = true)
#  |-- value: double (nullable = true)

# %%
df_meas.select("parameter").distinct().show()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 62, Finished, Available, Finished, False)
# +----------------+
# |       parameter|
# +----------------+
# |relativehumidity|
# |     temperature|
# |           um003|
# |              co|
# |             pm1|
# |            pm10|
# |            pm25|
# |             so2|
# |              o3|
# |             nox|
# |             no2|
# |              no|
# +----------------+

# %%
print("Before dropping duplicates:", df_meas.count())
df_meas = df_meas.drop_duplicates()
print("After dropping duplicates:", df_meas.count())
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 63, Finished, Available, Finished, False)
# Before dropping duplicates: 1523629
# After dropping duplicates: 1523629

# %%
df_meas = df_meas.filter(df_meas["datetime_from_utc"] <= df_meas["datetime_to_utc"])
print("After filtering of dates:", df_meas.count())
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 64, Finished, Available, Finished, False)
# After filtering of dates: 1523629

# %%
df_meas = df_meas.filter(
    ((df_meas["parameter"] == "relativehumidity") &
     (df_meas["value"].between(0, 100))) |
    ((df_meas["parameter"] == "temperature") &
     (df_meas["value"].between(-100, 100))) |
    ((~df_meas["parameter"].isin(["relativehumidity", "temperature"])) &
     (df_meas["value"] >= 0))
)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 66, Finished, Available, Finished, False)

# %%
df_meas = df_meas.na.drop(how = "all")
df_meas.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 67, Finished, Available, Finished, False)
# 1523629

# %%
df_meas = df_meas.dropDuplicates(["sensor_id", "datetime_from_utc"])
df_meas.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 68, Finished, Available, Finished, False)
# 1523629

# %%
df_meas = df_meas.na.drop(subset=["sensor_id","location_id","parameter","value","datetime_from_utc"])
df_meas.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 69, Finished, Available, Finished, False)
# 1523629

# %%
numberRows = df_meas.count()
print("Total amount NULL - values between columns:")
for k in df_meas.columns:
    nullRows = df_meas.filter(df_meas[f"{k}"].isNull()).count()
    print(f"{k} - {nullRows}")
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 70, Finished, Available, Finished, False)
# Total amount NULL - values between columns:
# datetime_from_utc - 0
# datetime_to_utc - 0
# location_id - 0
# parameter - 0
# sensor_id - 0
# value - 0

# %%
df_meas.printSchema()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 71, Finished, Available, Finished, False)
# root
#  |-- datetime_from_utc: timestamp (nullable = true)
#  |-- datetime_to_utc: timestamp (nullable = true)
#  |-- location_id: integer (nullable = true)
#  |-- parameter: string (nullable = true)
#  |-- sensor_id: integer (nullable = true)
#  |-- value: double (nullable = true)

# %%
from pyspark.sql import functions as F
countNaN_df_meas = df_meas.filter(F.isnan("value"))
print(f"Total count of NaN values:{countNaN_df_meas.count()}")
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 72, Finished, Available, Finished, False)
# Total count of NaN values:0

# %%
print("Checking total data by parameter before IQR - outliers:")
df_meas.groupBy("parameter").count().show()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 73, Finished, Available, Finished, False)
# Checking total data by parameter before IQR - outliers:
# +----------------+------+
# |       parameter| count|
# +----------------+------+
# |             so2|107003|
# |relativehumidity|134122|
# |     temperature|139754|
# |           um003|130846|
# |              co|108084|
# |             pm1|131445|
# |             nox| 79473|
# |              o3|169342|
# |            pm10| 49089|
# |             no2|118870|
# |              no| 74650|
# |            pm25|280951|
# +----------------+------+

# %%
display(df_meas)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 74, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 617cb1e6-b20d-455f-982a-07a1654a7f25)

# %%
df_meas.printSchema()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 75, Finished, Available, Finished, False)
# root
#  |-- datetime_from_utc: timestamp (nullable = true)
#  |-- datetime_to_utc: timestamp (nullable = true)
#  |-- location_id: integer (nullable = true)
#  |-- parameter: string (nullable = true)
#  |-- sensor_id: integer (nullable = true)
#  |-- value: double (nullable = true)

# %%
from pyspark.sql.functions import year, month, dayofmonth, hour, dayofweek
df_meas = df_meas.withColumn("year", year("datetime_from_utc"))
df_meas = df_meas.withColumn("month", month("datetime_from_utc"))
df_meas = df_meas.withColumn("day", dayofmonth("datetime_from_utc"))
df_meas = df_meas.withColumn("day_of_week", dayofweek("datetime_from_utc"))
df_meas = df_meas.withColumn("hour", hour("datetime_from_utc"))
display(df_meas)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 76, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 46481b6a-d3de-4121-a18a-1eebb44638f2)

# %%
# from pyspark.sql.functions import col,exp
# def iqr_outlier_treatment(dataframe,parameter, column, factor =1.5):
#     list_parameter = df_meas.select(f"{parameter}").distinct()
#     for p in list_parameter:

#         # calculate Q1, Q3 and IQR
#         quantiles = dataframe.approxQuantile(column, [0.25, 0.75], 0.01)
#         q1, q3 = quantiles[0], quantiles[1]
#         iqr = q3 - q1

#         # define the upper and lower bounds for outliers
#         lower_bound = q1 - factor * iqr
#         upper_bound = q3 + factor * iqr
 
#         # filter outliers and update the DataFrame
#         dataframe = dataframe.filter((col(column) >= lower_bound) & (col(column) <= upper_bound))
#     return dataframe

# df_meas = iqr_outlier_treatment(df_meas, "parameter", "value")
# display(df_meas)
# print(df_meas.count())
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 77, Finished, Available, Finished, False)

# %%
df_meas.write.format("delta").mode("overwrite").option("overwriteSchema","true").saveAsTable("Silver.dbo.silver_openaq_measurements")
print("Saved in Silver!")
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 78, Finished, Available, Finished, False)
# Saved in Silver!

# %%
from pyspark.sql.functions import to_date
df_meas = spark.sql("SELECT * FROM Silver.dbo.silver_openaq_measurements")
df_meas = df_meas.withColumn("date", to_date("datetime_from_utc"))

df_meas.write.format("delta").mode("overwrite").option("overwriteSchema","true").saveAsTable("Silver.dbo.silver_openaq_measurements")
print("Saved in Silver!")
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 79, Finished, Available, Finished, False)
# Saved in Silver!

# %%
df_bank = spark.sql("SELECT * FROM Silver.dbo.raw_world_bank")
display(df_bank)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 80, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 448618ec-530e-4b33-a041-68392ee3c811)

# %%
df_bank = df_bank.select("`country.value`", "date", "value")
df_bank = df_bank.dropDuplicates()
count_of_dates = df_bank.select("date").distinct().count()
total_count = df_bank.count()
print("Total count of unique date:", count_of_dates)
print("Total count of rows at bank-dataset:", total_count)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 81, Finished, Available, Finished, False)
# Total count of unique date: 50
# Total count of rows at bank-dataset: 50

# %%
display(df_bank)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 82, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, e49f7a5f-a784-405d-a1b5-315447eed7d4)

# %%
df_bank.printSchema()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 83, Finished, Available, Finished, False)
# root
#  |-- country.value: string (nullable = true)
#  |-- date: long (nullable = true)
#  |-- value: long (nullable = true)

# %%
from pyspark.sql.functions import col
df_bank = df_bank.withColumn("date",col("date").cast("int"))
df_bank.printSchema()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 84, Finished, Available, Finished, False)
# root
#  |-- country.value: string (nullable = true)
#  |-- date: integer (nullable = true)
#  |-- value: long (nullable = true)

# %%
df_bank = df_bank.withColumnRenamed("date","year")
df_bank.printSchema()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 85, Finished, Available, Finished, False)
# root
#  |-- country.value: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- value: long (nullable = true)

# %%
df_bank = df_bank.filter((df_bank["year"] >= 0) & (df_bank["value"] >= 0))
df_bank.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 86, Finished, Available, Finished, False)
# 49

# %%
from pyspark.sql.functions import *
display(df_bank.select([count(when(col(f"`{c}`").isNull(),c )).alias(c) for c in df_bank.columns]))
display(df_bank.select([count(when(isnan(col(c)), c)).alias(c) for c in ["year", "value"]]))
df_bank.columns
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 87, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, d6e41d89-8d9f-4faf-b598-0ab0d9ae2274)
# SynapseWidget(Synapse.DataFrame, 957a76f6-26d1-4a33-8f27-238d6a58f5b2)
# ['country.value', 'year', 'value']

# %%
df_bank.write.format("delta").mode("overwrite").saveAsTable("Silver.dbo.silver_world_bank_gdp")
print("Saved in Silver!")
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 88, Finished, Available, Finished, False)
# Saved in Silver!

# %%
df_currency = spark.sql("SELECT * FROM Silver.dbo.raw_ecb_fx")
display(df_currency)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 89, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 91457095-d5ad-4a70-af9f-201e4eab798d)

# %%
df_currency = df_currency.select("TIME_PERIOD", "OBS_VALUE")
df_currency.printSchema()
df_currency.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 90, Finished, Available, Finished, False)
# root
#  |-- TIME_PERIOD: date (nullable = true)
#  |-- OBS_VALUE: double (nullable = true)
# 7059

# %%
from pyspark.sql.functions import isnan

df_currency = df_currency.filter((df_currency["OBS_VALUE"] > 0) & (df_currency["OBS_VALUE"].isNotNull()) & (~isnan(df_currency["OBS_VALUE"])))
df_currency = df_currency.filter(df_currency["TIME_PERIOD"].isNotNull())
df_currency = df_currency.dropDuplicates()
df_currency = df_currency.dropDuplicates(["TIME_PERIOD"])
df_currency.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 91, Finished, Available, Finished, False)
# 6997

# %%
from pyspark.sql.functions import year, month, dayofmonth, dayofweek
df_currency = df_currency.withColumn('year', year(df_currency["TIME_PERIOD"]))
df_currency = df_currency.withColumn('month', month(df_currency["TIME_PERIOD"]))
df_currency = df_currency.withColumn('day', dayofmonth(df_currency["TIME_PERIOD"]))
df_currency = df_currency.withColumn('day_of_week', dayofweek(df_currency["TIME_PERIOD"]))
df_currency = df_currency.withColumnRenamed("TIME_PERIOD", "date")
df_currency = df_currency.withColumnRenamed("OBS_VALUE", "usd_eur_rate")
display(df_currency)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 92, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 29086069-1f47-4630-bc74-12f2d60c9831)

# %%
df_currency.write.format("delta").mode("overwrite").option("overwriteSchema", "true").saveAsTable("Silver.dbo.silver_ecb_fx")
print("Saved in Silver!")
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 93, Finished, Available, Finished, False)
# Saved in Silver!

# %%
import pandas as pd

URL = "https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv"

pdf = pd.read_csv(URL)
df_lookup = spark.createDataFrame(pdf)
display(df_lookup)
df_lookup.write.format("delta").mode("overwrite").option("overwriteSchema", "true").saveAsTable("Silver.dbo.silver_taxi_zone_lookup")
print("Saved in Silver!")
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 94, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, f44c683e-8785-4863-b393-ffc8b04d16bc)
# Saved in Silver!

# %%
df_lookup = df_lookup.dropDuplicates(['LocationID'])
df_lookup.count()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 95, Finished, Available, Finished, False)
# 265

# %%
from pyspark.sql.functions import *
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 96, Finished, Available, Finished, False)

# %%
start_date = '2022-01-01'
end_date = '2025-12-31'
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 97, Finished, Available, Finished, False)

# %%
date_df = spark.sql(f"""
SELECT sequence(to_date('{start_date}'),
to_date('{end_date}'),
interval 1 day) as date_seq """).selectExpr("explode(date_seq) as full_date")
dim_date = date_df.withColumn("year", year("full_date"))\
.withColumn("month", month("full_date"))\
.withColumn("day",dayofmonth("full_date"))\
.withColumn("day_of_week",dayofweek("full_date"))
dim_date = dim_date.withColumn("season", when(month("full_date").isin(12,1,2),'WINTER')\
.when(month("full_date").isin(3,4,5),'SPRING')\
.when(month("full_date").isin(6,7,8),'SUMMER')\
.otherwise('AUTUMN'))
display(dim_date)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 98, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, c649bc0d-adeb-4d7a-867a-bb8b90d13879)

# %%
dim_date.write.format("delta").mode("overwrite").option("overwriteSchema","true").saveAsTable("Silver.dbo.silver_lookup_date")
print("Saved in Silver!")
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 99, Finished, Available, Finished, False)
# Saved in Silver!

# %%
df = spark.sql("SELECT * FROM Silver.dbo.silver_openaq_measurements")
display(df)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 103, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, e8de550e-c07c-43eb-b1d0-438162d5b88e)

# %%
df = spark.sql("SELECT * FROM Silver.dbo.silver_nyc_taxi")
df.printSchema()
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 106, Finished, Available, Finished, False)
# root
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- total_outliers: integer (nullable = true)
#  |-- pickup_year: integer (nullable = true)
#  |-- pickup_month: integer (nullable = true)
#  |-- pickup_date: date (nullable = true)
#  |-- pickup_hour: integer (nullable = true)
#  |-- pickup_day_of_week: integer (nullable = true)
#  |-- pickup_day: integer (nullable = true)
#  |-- trip_duration_min: double (nullable = true)

# %%
df = spark.sql("SELECT * FROM Silver.dbo.silver_openaq_locations")
display(df)
# Out:
# StatementMeta(, e8cf2973-4d6a-48d2-80d5-c1766590f7a5, 108, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 5c951ea7-0897-4ed6-94f4-de103403b904)
